# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia01.csv",sep=",",parse_dates = ["ocorrencia_dia"])
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              81027               81027          INCIDENTE GRAVE
# 1              81030               81030                INCIDENTE
# 2              81023               81023          INCIDENTE GRAVE
# 3              81029               81029                INCIDENTE
# 4              81025               81025                INCIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         SÃO PAULO            SP                 SBSP     2022-10-09
# 1           VITÓRIA            ES                 SBVT     2022-10-09
# 2         AMERICANA            SP                 SDAI     2022-10-06
# 3    BELO HORIZONTE            MG                 SBBH     2022-10-06
# 4            MANAUS            AM                 SBEG     2022-10-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        16:30:00                    0
# 1        16:20:00                    0
# ...

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'VITÓRIA'

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              81030               81030                INCIDENTE
# 2              81023               81023          INCIDENTE GRAVE
# 3              81029               81029                INCIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1           VITÓRIA            ES                 SBVT     2022-10-09
# 2         AMERICANA            SP                 SDAI     2022-10-06
# 3    BELO HORIZONTE            MG                 SBBH     2022-10-06
#
#   ocorrencia_hora  total_recomendacoes
# 1        16:20:00                    0
# 2        15:30:00                    0
# 3         0:44:00                    0

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              81017               81017          INCIDENTE GRAVE
# 40              80978               80978                 ACIDENTE
#
#         ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10                GOIÂNIA            GO                 SBNV     2022-09-30
# 40  SANTA HELENA DE GOIÁS            GO                  ***     2022-09-09
#
#    ocorrencia_hora  total_recomendacoes
# 10        13:40:00                    0
# 40        15:40:00                    0

# %%
df.loc[:, 'ocorrencia_cidade']
# Out:
# 0                SÃO PAULO
# 1                  VITÓRIA
# 2                AMERICANA
# 3           BELO HORIZONTE
# 4                   MANAUS
#                ...
# 6764               PELOTAS
# 6765    LUCAS DO RIO VERDE
# 6766        RIO DE JANEIRO
# 6767                 BELÉM
# 6768        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 6769, dtype: object

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.ocorrencia_uf.is_unique
# Out:
# False

# %%
df.set_index('codigo_ocorrencia', inplace = True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 81027                           81027          INCIDENTE GRAVE
# 81030                           81030                INCIDENTE
# 81023                           81023          INCIDENTE GRAVE
# 81029                           81029                INCIDENTE
# 81025                           81025                INCIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 81027                     SÃO PAULO            SP                 SBSP
# 81030                       VITÓRIA            ES                 SBVT
# 81023                     AMERICANA            SP                 SDAI
# 81029                BELO HORIZONTE            MG                 SBBH
# 81025                        MANAUS            AM                 SBEG
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# ...

# %%
df.loc[40324]
# Out:
# codigo_ocorrencia2                        40324
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                       PELOTAS
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       SBPK
# ocorrencia_dia              2010-01-05 00:00:00
# ocorrencia_hora                        19:25:00
# total_recomendacoes                           0
# Name: 40324, dtype: object

# %%
df.reset_index(drop=True, inplace = True)

# %%
df.head(10)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao  ocorrencia_cidade  \
# 0               81027          INCIDENTE GRAVE          SÃO PAULO
# 1               81030                INCIDENTE            VITÓRIA
# 2               81023          INCIDENTE GRAVE          AMERICANA
# 3               81029                INCIDENTE     BELO HORIZONTE
# 4               81025                INCIDENTE             MANAUS
# 5               81019                 ACIDENTE       PORTO ALEGRE
# 6               81022                INCIDENTE             LOBATO
# 7               81021                 ACIDENTE  NOVA BANDEIRANTES
# 8               81009          INCIDENTE GRAVE            NAVIRAÍ
# 9               81012                INCIDENTE           LINHARES
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            SP                 SBSP     2022-10-09        16:30:00
# 1            ES                 SBVT     2022-10-09        16:20:00
# ...

# %%
df.loc[5,'ocorrencia_aerodromo'] = ''

# %%
df.head(10)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao  ocorrencia_cidade  \
# 0               81027          INCIDENTE GRAVE          SÃO PAULO
# 1               81030                INCIDENTE            VITÓRIA
# 2               81023          INCIDENTE GRAVE          AMERICANA
# 3               81029                INCIDENTE     BELO HORIZONTE
# 4               81025                INCIDENTE             MANAUS
# 5               81019                 ACIDENTE       PORTO ALEGRE
# 6               81022                INCIDENTE             LOBATO
# 7               81021                 ACIDENTE  NOVA BANDEIRANTES
# 8               81009          INCIDENTE GRAVE            NAVIRAÍ
# 9               81012                INCIDENTE           LINHARES
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            SP                 SBSP     2022-10-09        16:30:00
# 1            ES                 SBVT     2022-10-09        16:20:00
# ...

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 81027               81027                    GRAVE
# 1                 81030               81030                INCIDENTE
# 2                 81023               81023                    GRAVE
# 3                 81029               81029                INCIDENTE
# 4                 81025               81025                INCIDENTE
# ...                 ...                 ...                      ...
# 6764              40324               40324                INCIDENTE
# 6765              39527               39527                 ACIDENTE
# 6766              40211               40211                INCIDENTE
# 6767              40349               40349                INCIDENTE
# 6768              40351               40351                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.loc[df.ocorrencia_uf == "SP"]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 81027               81027          INCIDENTE GRAVE
# 2                 81023               81023          INCIDENTE GRAVE
# 13                81003               81003          INCIDENTE GRAVE
# 14                81001               81001                INCIDENTE
# 18                80997               80997                INCIDENTE
# ...                 ...                 ...                      ...
# 6741              39768               39768                INCIDENTE
# 6743              39847               39847                INCIDENTE
# 6751              39809               39809                INCIDENTE
# 6753              39828               39828                INCIDENTE
# 6759              40069               40069                 ACIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %% [markdown]
# Ocorrencia_uff
# **
#
#
# ocorrencia_aerodromo
# ***
# **NI
#
#
# ocorrencia hora
#
# NULL

# %%
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              81027               81027          INCIDENTE GRAVE
# 1              81030               81030                INCIDENTE
# 2              81023               81023          INCIDENTE GRAVE
# 3              81029               81029                INCIDENTE
# 4              81025               81025                INCIDENTE
# 5              81019               81019                 ACIDENTE
# 6              81022               81022                INCIDENTE
# 7              81021               81021                 ACIDENTE
# 8              81009               81009          INCIDENTE GRAVE
# 9              81012               81012                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0          SÃO PAULO            SP                 SBSP     2022-10-09
# 1            VITÓRIA            ES                 SBVT     2022-10-09
# ...

# %%
df.loc[df.ocorrencia_aerodromo == '***', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              81027               81027          INCIDENTE GRAVE
# 1              81030               81030                INCIDENTE
# 2              81023               81023          INCIDENTE GRAVE
# 3              81029               81029                INCIDENTE
# 4              81025               81025                INCIDENTE
# 5              81019               81019                 ACIDENTE
# 6              81022               81022                INCIDENTE
# 7              81021               81021                 ACIDENTE
# 8              81009               81009          INCIDENTE GRAVE
# 9              81012               81012                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0          SÃO PAULO            SP                 SBSP     2022-10-09
# 1            VITÓRIA            ES                 SBVT     2022-10-09
# ...

# %%
df.replace(['**NI','NULL','**','***',"****"], pd.NA, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  4
# ocorrencia_aerodromo        2618
# ocorrencia_dia                 0
# ocorrencia_hora                2
# total_recomendacoes            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  4
# ocorrencia_aerodromo        2618
# ocorrencia_dia                 0
# ocorrencia_hora                2
# total_recomendacoes            0
# dtype: int64

# %%
df.fillna(10, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 81027               81027          INCIDENTE GRAVE
# 1                 81030               81030                INCIDENTE
# 2                 81023               81023          INCIDENTE GRAVE
# 3                 81029               81029                INCIDENTE
# 4                 81025               81025                INCIDENTE
# ...                 ...                 ...                      ...
# 6764              40324               40324                INCIDENTE
# 6765              39527               39527                 ACIDENTE
# 6766              40211               40211                INCIDENTE
# 6767              40349               40349                INCIDENTE
# 6768              40351               40351                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  4
# ocorrencia_aerodromo        2618
# ocorrencia_dia                 0
# ocorrencia_hora                2
# total_recomendacoes            2
# dtype: int64

# %%
df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  4
# ocorrencia_aerodromo        2618
# ocorrencia_dia                 0
# ocorrencia_hora                2
# total_recomendacoes            0
# dtype: int64

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              81027               81027          INCIDENTE GRAVE
# 1              81030               81030                INCIDENTE
# 2              81023               81023          INCIDENTE GRAVE
# 3              81029               81029                INCIDENTE
# 4              81025               81025                INCIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         SÃO PAULO            SP                 SBSP     2022-10-09
# 1           VITÓRIA            ES                 SBVT     2022-10-09
# 2         AMERICANA            SP                 SDAI     2022-10-06
# 3    BELO HORIZONTE            MG                 SBBH     2022-10-06
# 4            MANAUS            AM                 SBEG     2022-10-05
#
#   ocorrencia_hora  total_recomendacoes  total_recomendacoes_bkp
# 0        16:30:00                    0                        0
# ...

# %%
df.drop(['total_recomendacoes_bkp'],axis=1, inplace = True)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              81027               81027          INCIDENTE GRAVE
# 1              81030               81030                INCIDENTE
# 2              81023               81023          INCIDENTE GRAVE
# 3              81029               81029                INCIDENTE
# 4              81025               81025                INCIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         SÃO PAULO            SP                 SBSP     2022-10-09
# 1           VITÓRIA            ES                 SBVT     2022-10-09
# 2         AMERICANA            SP                 SDAI     2022-10-06
# 3    BELO HORIZONTE            MG                 SBBH     2022-10-06
# 4            MANAUS            AM                 SBEG     2022-10-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        16:30:00                    0
# 1        16:20:00                    0
# ...

# %%
df.dropna()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 81027               81027          INCIDENTE GRAVE
# 1                 81030               81030                INCIDENTE
# 2                 81023               81023          INCIDENTE GRAVE
# 3                 81029               81029                INCIDENTE
# 4                 81025               81025                INCIDENTE
# ...                 ...                 ...                      ...
# 6760              40414               40414                INCIDENTE
# 6762              40215               40215                INCIDENTE
# 6764              40324               40324                INCIDENTE
# 6767              40349               40349                INCIDENTE
# 6768              40351               40351                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 81027               81027          INCIDENTE GRAVE
# 1                 81030               81030                INCIDENTE
# 2                 81023               81023          INCIDENTE GRAVE
# 3                 81029               81029                INCIDENTE
# 4                 81025               81025                INCIDENTE
# ...                 ...                 ...                      ...
# 6764              40324               40324                INCIDENTE
# 6765              39527               39527                 ACIDENTE
# 6766              40211               40211                INCIDENTE
# 6767              40349               40349                INCIDENTE
# 6768              40351               40351                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dropna(subset=['ocorrencia_uf'])
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 81027               81027          INCIDENTE GRAVE
# 1                 81030               81030                INCIDENTE
# 2                 81023               81023          INCIDENTE GRAVE
# 3                 81029               81029                INCIDENTE
# 4                 81025               81025                INCIDENTE
# ...                 ...                 ...                      ...
# 6764              40324               40324                INCIDENTE
# 6765              39527               39527                 ACIDENTE
# 6766              40211               40211                INCIDENTE
# 6767              40349               40349                INCIDENTE
# 6768              40351               40351                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.drop_duplicates()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 81027               81027          INCIDENTE GRAVE
# 1                 81030               81030                INCIDENTE
# 2                 81023               81023          INCIDENTE GRAVE
# 3                 81029               81029                INCIDENTE
# 4                 81025               81025                INCIDENTE
# ...                 ...                 ...                      ...
# 6764              40324               40324                INCIDENTE
# 6765              39527               39527                 ACIDENTE
# 6766              40211               40211                INCIDENTE
# 6767              40349               40349                INCIDENTE
# 6768              40351               40351                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...
